# %%
# %%html
# <a href="https://www.kaggle.com/cashncarry/fifa-21-players-teams-full-database">Showing Text</a>
# Out:
# <a href="https://www.kaggle.com/cashncarry/fifa-21-players-teams-full-database">Showing Text</a>

# %%
import pandas as pd

# %%
fifa_dataset=pd.read_csv("fifa.csv")

# %%
fifa_dataset
# Out:
#            ID               Name                      FullName  Age  Height  \
# 0      158023           L. Messi                  Lionel Messi   33     170
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   35     187
# 2      188545     R. Lewandowski            Robert Lewandowski   31     185
# 3      190871          Neymar Jr    Neymar da Silva Santos Jr.   28     175
# 4      192985       K. De Bruyne               Kevin De Bruyne   29     181
# ...       ...                ...                           ...  ...     ...
# 19015  261932      Chen Guoliang                 Guoliang Chen   21     186
# 19016  245024       Wang Shilong                  Shilong Wang   19     176
# 19017  260623          M. Wright                   Mark Wright   33     178
# 19018  243725         D. Collins                Darren Collins   19     174
# 19019  262760           N. Logue                  Nathan Logue   20     178
#
# ...

# %%
fifa_dataset.shape
# Out:
# (19020, 90)

# %%
fifa_dataset.columns
# Out:
# Index(['ID', 'Name', 'FullName', 'Age', 'Height', 'Weight', 'PhotoUrl',
#        'Nationality', 'Overall', 'Potential', 'Growth', 'TotalStats',
#        'BaseStats', 'Positions', 'BestPosition', 'Club', 'ValueEUR', 'WageEUR',
#        'ReleaseClause', 'ClubPosition', 'ContractUntil', 'ClubNumber',
#        'ClubJoined', 'OnLoad', 'NationalTeam', 'NationalPosition',
#        'NationalNumber', 'PreferredFoot', 'IntReputation', 'WeakFoot',
#        'SkillMoves', 'AttackingWorkRate', 'DefensiveWorkRate', 'PaceTotal',
#        'ShootingTotal', 'PassingTotal', 'DribblingTotal', 'DefendingTotal',
#        'PhysicalityTotal', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
# ...

# %%
fifa_dataset[['Name', 'Age']].head()
# Out:
#                 Name  Age
# 0           L. Messi   33
# 1  Cristiano Ronaldo   35
# 2     R. Lewandowski   31
# 3          Neymar Jr   28
# 4       K. De Bruyne   29

# %%
fifa_dataset.iloc[0]
# Out:
# ID                 158023
# Name             L. Messi
# FullName     Lionel Messi
# Age                    33
# Height                170
#                  ...
# RWBRating              69
# LBRating               65
# CBRating               55
# RBRating               65
# GKRating               22
# Name: 0, Length: 90, dtype: object

# %%
fifa_dataset['Height'].value_counts()
# Out:
# 180    1451
# 178    1247
# 185    1239
# 183    1162
# 175    1141
# 188     954
# 182     876
# 184     832
# 186     785
# 181     723
# 177     723
# 187     709
# 176     672
# 179     645
# 190     613
# 173     602
# 174     524
# 170     510
# 191     479
# 189     459
# 172     438
# 193     325
# 192     310
# 171     264
# 168     206
# 194     189
# 169     166
# 195     147
# 196     143
# 167     108
# 165      81
# 166      69
# 197      59
# 198      42
# 163      28
# 164      25
# 199      19
# 201      11
# 200       8
# 162       7
# 160       7
# 202       6
# 161       5
# 158       4
# 156       2
# 159       2
# 157       1
# 203       1
# 206       1
# Name: Height, dtype: int64

# %%
fifa_dataset.loc[1:9]
# Out:
#        ID               Name                      FullName  Age  Height  \
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro   35     187
# 2  188545     R. Lewandowski            Robert Lewandowski   31     185
# 3  190871          Neymar Jr    Neymar da Silva Santos Jr.   28     175
# 4  192985       K. De Bruyne               Kevin De Bruyne   29     181
# 5  200389           J. Oblak                     Jan Oblak   27     188
# 6  231747          K. Mbappé                 Kylian Mbappé   21     178
# 7  203376        V. van Dijk               Virgil van Dijk   28     193
# 8  192448      M. ter Stegen         Marc-André ter Stegen   28     187
# 9  167495           M. Neuer                  Manuel Neuer   34     193
#
#    Weight                                          PhotoUrl  Nationality  \
# 1      83  https://cdn.sofifa.com/players/020/801/21_60.png     Portugal
# 2      81  https://cdn.sofifa.com/players/188/545/21_60.png       Poland
# ...

# %%
fifa_dataset.describe()
# Out:
#                   ID           Age        Height        Weight       Overall  \
# count   19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean   228546.410305     24.715352    181.300473     75.042166     65.937960
# std     27300.239340      4.763147      6.837172      7.022764      6.878822
# min        41.000000     15.000000    156.000000     48.000000     47.000000
# 25%    211684.000000     21.000000    176.000000     70.000000     62.000000
# 50%    234052.000000     24.000000    181.000000     75.000000     66.000000
# 75%    251163.250000     28.000000    186.000000     80.000000     70.000000
# max    263848.000000     53.000000    206.000000    110.000000     93.000000
#
#           Potential        Growth    TotalStats     BaseStats      ValueEUR  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  1.902000e+04
# mean      71.068034      5.130074   1602.329022    357.596951  2.981759e+06
# ...

# %%
fifa_dataset[fifa_dataset.Age == 80].head()
# Out:
# Empty DataFrame
# ...

# %%
# %matplotlib inline

# %%
fifa_dataset.Age.hist()
# Out:
# <AxesSubplot:>

# %%
fifa_dataset.Height.hist()
# Out:
# <AxesSubplot:>
